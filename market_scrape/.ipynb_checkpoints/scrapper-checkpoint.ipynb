# %%
import pandas as pd
from coredotfinance.data import KrxReader
krx = KrxReader()
import dart_fss as dart

# %%
corp_df = krx.listed_company()
corp_df
# Out:
#         종목코드     종목명    시장구분    소속부    업종코드                      업종명 결산월  \
# 0     060310      3S  KOSDAQ  중견기업부  032602                 전자부품 제조업  03
# 1     095570  AJ네트웍스   KOSPI         147603          산업용 기계 및 장비 임대업  12
# 2     006840   AK홀딩스   KOSPI         116409                   기타 금융업  12
# 3     054620  APS홀딩스  KOSDAQ  중견기업부  116409                   기타 금융업  12
# 4     265520   AP시스템  KOSDAQ  우량기업부  032902            특수 목적용 기계 제조업  12
# ...      ...     ...     ...    ...     ...                      ...  ..
# 2501  189980  흥국에프엔비  KOSDAQ  우량기업부  031102          비알코올음료 및 얼음 제조업  12
# 2502  000540    흥국화재   KOSPI         116501                      보험업  12
# 2503  003280    흥아해운   KOSPI         085001                   해상 운송업  12
# 2504  037440      희림  KOSDAQ  우량기업부  137201  건축기술 엔지니어링 및 관련 기술 서비스업  12
# 2505  238490      힘스  KOSDAQ  우량기업부  032902            특수 목적용 기계 제조업  12
#
#      지정자문인      상장주식수     액면가           자본금    통화구분                대표이사  \
# 0            46271513   500.0   23135756500  원(KRW)                 김세완
# 1            46822295 1,000.0   46822295000  원(KRW)             박대현 손삼달
# 2            13247561 5,000.0   66237805000  원(KRW)    채형석 이석주(각자 대표이사)
# 3            20394221   500.0   10197110500  원(KRW)                 정기로
# 4            15281421   500.0    7640710500  원(KRW)                 김영주
# ...    ...        ...     ...           ...     ...                 ...
# 2501         39997771   100.0    3999777100  원(KRW)             박철범 오길영
# 2502         64242645 5,000.0  325821225000  원(KRW)                 임규준
# 2503        240424899   500.0  120212449500  원(KRW)                 이환구
# 2504         13922475   500.0    6961237500  원(KRW)  정영균 이목운 허철호 (각자대표)
# 2505         11312236   500.0    5656118000  원(KRW)                 김주환
#
#               대표전화                                                 주소
# 0      02-896-9474                      서울특별시 금천구 가산디지털1로 75-24 1310호
# 1     02-6363-9999                        서울특별시 송파구 정의로8길 9 (문정동AJ빌딩)
# 2      02-768-2923                               서울특별시 마포구 양화로 188 -
# 3     031-776-1800                     경기도 화성시 동탄면 동탄산단9길 23-12 (동탄면)
# 4     031-379-2700                     경기도 화성시  동탄면 동탄산단8길 15-5 &nbsp
# ...            ...                                                ...
# 2501   02-572-2446                  서울특별시 서초구 마방로 60 24층 (양재동 트러스트타워)
# 2502  02-2002-6000                                 서울특별시 종로구 새문안로 68
# 2503  02-3449-3000  서울특별시 중구 남대문로9길 39 서울시 중구 남대문로9길 39(을지로1가 부림빌딩...
# 2504  02-3410-9219                               서울특별시 강동구 상일로6길 39-
# 2505  032-821-2511                           인천광역시 남동구 남동서로 126 &nbsp
#
# [2506 rows x 15 columns]

# %%
def get_report(key, corp_code, year, rpt_code):
    import requests
    from bs4 import BeautifulSoup
    from lxml import html
    from urllib.request import Request, urlopen
    from urllib.parse import urlencode, quote_plus, unquote
    
    url = 'https://opendart.fss.or.kr/api/fnlttSinglAcntAll.json'
    params = {
        'crtfc_key': key,
        'corp_code': corp_code,
        'bsns_year': year,
        'reprt_code': rpt_code,
        'fs_div': 'OFS'
    }
    # response = requests.get(url, params=params).content.decode('UTF-8')
    response = requests.get(url, params=params).json()
    print(response)
    
    # xml_obj = BeautifulSoup(response, 'html.parser')
    # rows = xml_obj.findAll('list')
    # return rows

# %%
def get_corp_list(key):
    import requests
    from io import BytesIO
    from zipfile import ZipFile
    from xml.etree.ElementTree import parse
    from bs4 import BeautifulSoup
    from lxml import html
    from urllib.request import Request, urlopen
    from urllib.parse import urlencode, quote_plus, unquote
    
    url = 'https://opendart.fss.or.kr/api/corpCode.xml'
    params = {'crtfc_key': key}
    response = requests.get(url, params=params).content
    
    with ZipFile(BytesIO(response)) as zipfile:
        zipfile.extractall('corpCode')
    
    xmlTree = parse('./corpCode/corpCode.xml')
    root = xmlTree.getroot()
    raw_list = root.findall('list')
    
    corp_list = {}
    for i in range(len(raw_list)):
        corp_code = raw_list[1].findtext('corp_code')
        # corp_name = raw_list[1].findtext('corp_name')
        stock_code = raw_list[1].findtext('stock_code')
        # modify_date = raw_list[1].findtext('modify_date')
        
        corp_list[stock_code] = corp_code
    
    return corp_list

# %%
API_KEY = 'a1f670c01770f59e59cd35917d87002ed5523869'
YEAR = '2018'
RPT_CODE = '11011'

corp_list = get_corp_list(API_KEY)

# %%
get_items(API_KEY, corp_list['060310'], YEAR, RPT_CODE)
# fs_list = []
# for i in range(len(corp_df)):
#     if i == 1:
#         break
    
#     tricker = corp_df.loc[i, '종목코드']
#     field_code = corp_df.loc[i, '업종코드']
#     get_items(API_KEY, corp_code, YEAR, RPT_CODE)
    
# fs_df = pd.DataFrame(fs_list, columns=[
#     '
# ])
# fs_df
